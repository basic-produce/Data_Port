# %%
# import libraries and data
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8) # Adjust the configuration of the plots we will create

#Read in the data
df= pd.read_csv(r'C:\Users\phamt\OneDrive\Tài liệu\Data Set\movies.csv')

# %%
#Looking at some unique value
uvalue, countu=np.unique(df['company'], return_index= True)
uvalue_re=uvalue.reshape(-1,1)
print(uvalue_re)
count_uvalue = len(uvalue)
print('Total number of film companies: ', count_uvalue)
# Out:
# [['"DIA" Productions GmbH & Co. KG']
#  ['"Weathering With You" Film Partners']
#  ['.406 Production']
#  ...
#  ['i5 Films']
#  ['micro_scope']
#  ['thefyzz']]
# Total number of film companies:  1475

# %%
df['company']
# Out:
# 0                    Warner Bros.
# 1               Columbia Pictures
# 2                       Lucasfilm
# 3              Paramount Pictures
# 4                  Orion Pictures
#                   ...
# 7663                          NaN
# 7664    Cactus Blue Entertainment
# 7665             Embi Productions
# 7666                          NaN
# 7667                  PK 65 Films
# Name: company, Length: 7668, dtype: object

# %%
# Check for missing data
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, pct_missing))
    #print (pct_missing)
    #or
    df.isnull().sum()
# Out:
# name - 0.0%
# rating - 0.0%
# genre - 0.0%
# year - 0.0%
# released - 0.0%
# score - 0.0%
# votes - 0.0%
# director - 0.0%
# writer - 0.0%
# star - 0.0%
# country - 0.0%
# budget - 0.0%
# gross - 0.0%
# company - 0.0%
# runtime - 0.0%

# %%
#There are some missing data so I gonna drop those
df=df.dropna()

# %%
df.head(20)
# Out:
#                                               name rating      genre  year  \
# 0                                      The Shining      R      Drama  1980
# 1                                  The Blue Lagoon      R  Adventure  1980
# 2   Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                        Airplane!     PG     Comedy  1980
# 4                                       Caddyshack      R     Comedy  1980
# 5                                  Friday the 13th      R     Horror  1980
# 6                               The Blues Brothers      R     Action  1980
# 7                                      Raging Bull      R  Biography  1980
# 8                                      Superman II     PG     Action  1980
# 9                                  The Long Riders      R  Biography  1980
# 10                           Any Which Way You Can     PG     Action  1980
# ...

# %%
# Change data type for columns

#df['budget']=df['budget'].astype('int64')

#df['gross']=df['gross'].astype('int64')

df['released']=df['released'].astype('str')

# can not work while there are null value

# %%
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# Edit released into year
df['corected_year'] = df['released'].astype(str).str.split(',').str[-1]
df['corected_year'] = df['corected_year'].astype(str).str.split(' ').str[1]
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
df.sort_values(by=['gross'], inplace=False, ascending=False)
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
# ...                                          ...    ...     ...   ...
# 7663                                More to Life    NaN   Drama  2020
# 7664                                 Dream Round    NaN  Comedy  2020
# 7665                               Saving Mbango    NaN   Drama  2020
# 7666                                It's Just Us    NaN   Drama  2020
# 7667                                   Tee em el    NaN  Horror  2020
#
#                                released  score      votes       director  \
# ...

# %%
# displayed all the index
pd.set_option('display.max_row', None)

# %%
# Drop any diplicates
df['company'].drop_duplicates().sort_values(ascending=False, inplace=False)
# Out:
# 7129                                              thefyzz
# 5664                                          micro_scope
# 6412                             iDeal Partners Film Fund
# 4007                                             i5 Films
# 6793                                           i am OTHER
# 6420                                                 erbp
# 3776                                       double A Films
# 524                             Zupnik-Curtis Enterprises
# 3330                          Zucker Brothers Productions
# 146                                      Zoetrope Studios
# 2213                                   Zeta Entertainment
# 6222                        Zentropa International Norway
# 3368                              Zentropa Entertainments
# 535                                  Zenith Entertainment
# 5180                                      Zazen Produções
# 3193                                          ZapPictures
# ...

# %%
# Budget high corelation 
# Company budget correlated with gross

# %%
# Scatter plot with budget vs gross

plt.scatter(x=df['budget'], y=df['gross'])
plt.title('Budget vs Gross Earning')
plt.xlabel('Budget')
plt.ylabel('Gross')
# Out:
# Text(0, 0.5, 'Gross')

# %%
# Plot the budget vs gross using seaborn - regression plot

sns.regplot(x='budget', y='gross', data = df, scatter_kws={"color": "orange"}, line_kws={"color":"green"})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
# Looking at correlation

# %%
df.corr(method='pearson') #pearson, kendall, spearman
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.097995  0.222945  0.329321  0.257486  0.120811
# score    0.097995  1.000000  0.409182  0.076254  0.186258  0.399451
# votes    0.222945  0.409182  1.000000  0.442429  0.630757  0.309212
# budget   0.329321  0.076254  0.442429  1.000000  0.740395  0.320447
# gross    0.257486  0.186258  0.630757  0.740395  1.000000  0.245216
# runtime  0.120811  0.399451  0.309212  0.320447  0.245216  1.000000

# %%
# Correlation between budget and gross is kinda high (0.74)
# We could say larger the budget -> larger the profit

# %%
df.head(10)
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
# 5                                 Friday the 13th      R     Horror  1980
# 6                              The Blues Brothers      R     Action  1980
# 7                                     Raging Bull      R  Biography  1980
# 8                                     Superman II     PG     Action  1980
# 9                                 The Long Riders      R  Biography  1980
#
#                             released  score      votes            director  \
# 0      June 13, 1980 (United States)    8.4   927000.0     Stanley Kubrick
# ...

# %%
# Putting correlation matrix on heatmap for better visualization 
correlation_matrix  = df.corr(method='spearman')
sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation between Budget and Gross')
plt.xlabel('Movie feature')
plt.ylabel('Movie feature')
plt.show()

# %%
# Look at all the field by making all the index numeric 
# Simply saying is turn all the characters to numbers
# The point is to see how data in string type like (company, director, genre, ...) affect the gross earning 
# This feature is under logic consideration...
df_numerized = df

for col_name in df_numerized.columns:
    if (df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name] = df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes
df_numerized.head(10)
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  6587       6      6  1980      1705    8.4   927000.0      2589    4014
# 1  5573       6      1  1980      1492    5.8    65000.0      2269    1632
# 2  5142       4      0  1980      1771    8.7  1200000.0      1111    2567
# 3   286       4      4  1980      1492    7.7   221000.0      1301    2000
# 4  1027       6      4  1980      1543    7.3   108000.0      1054     521
# 5  2109       6     10  1980      2502    6.4   123000.0      2528    4362
# 6  5574       6      0  1980      1771    7.9   188000.0      1412     838
# 7  4436       6      3  1980       699    8.2   330000.0      1829    1769
# 8  5281       4      0  1980      1753    6.8   101000.0      2306    1979
# 9  6213       6      3  1980      2286    7.0    10000.0      2864     423
#
#    star  country      budget        gross  company  runtime  corected_year
# ...

# %%
df.head(10)
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  6587       6      6  1980      1705    8.4   927000.0      2589    4014
# 1  5573       6      1  1980      1492    5.8    65000.0      2269    1632
# 2  5142       4      0  1980      1771    8.7  1200000.0      1111    2567
# 3   286       4      4  1980      1492    7.7   221000.0      1301    2000
# 4  1027       6      4  1980      1543    7.3   108000.0      1054     521
# 5  2109       6     10  1980      2502    6.4   123000.0      2528    4362
# 6  5574       6      0  1980      1771    7.9   188000.0      1412     838
# 7  4436       6      3  1980       699    8.2   330000.0      1829    1769
# 8  5281       4      0  1980      1753    6.8   101000.0      2306    1979
# 9  6213       6      3  1980      2286    7.0    10000.0      2864     423
#
#    star  country      budget        gross  company  runtime  corected_year
# ...

# %%
correlation_matrix  = df_numerized.corr(method='spearman')
sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation between Budget and Gross')
plt.xlabel('Movie feature')
plt.ylabel('Movie feature')
plt.show()

# %%
df_numerized.corr()
# Out:
#                    name    rating     genre      year  released     score  \
# name           1.000000 -0.008069  0.016355  0.011453 -0.010480  0.017097
# rating        -0.008069  1.000000  0.072423  0.008779  0.017208 -0.001314
# genre          0.016355  0.072423  1.000000 -0.081261  0.030429  0.027965
# year           0.011453  0.008779 -0.081261  1.000000  0.000077  0.097995
# released      -0.010480  0.017208  0.030429  0.000077  1.000000  0.042148
# score          0.017097 -0.001314  0.027965  0.097995  0.042148  1.000000
# votes          0.013088  0.033225 -0.145307  0.222945  0.016154  0.409182
# director       0.009079  0.019483 -0.015258 -0.020795 -0.001526  0.009559
# writer         0.009081 -0.005921  0.006567 -0.008656 -0.002784  0.019416
# star           0.006472  0.013405 -0.005477 -0.027242  0.015805 -0.001609
# country       -0.010737  0.081244 -0.037615 -0.070938 -0.023408 -0.133348
# budget         0.023970 -0.176002 -0.356564  0.329321  0.014683  0.076254
# ...

# %%
correlation_mat = df_numerized.corr()
corr_pairs = correlation_mat.unstack()
corr_pairs
# Out:
# name           name             1.000000
#                rating          -0.008069
#                genre            0.016355
#                year             0.011453
#                released        -0.010480
#                score            0.017097
#                votes            0.013088
#                director         0.009079
#                writer           0.009081
#                star             0.006472
#                country         -0.010737
#                budget           0.023970
#                gross            0.005533
#                company          0.009211
#                runtime          0.010392
#                corected_year    0.009775
# rating         name            -0.008069
#                rating           1.000000
#                genre            0.072423
#                year             0.008779
#                released         0.017208
#                score           -0.001314
#                votes            0.033225
# ...

# %%
corr_pairs['company']
# Out:
# name             0.009211
# rating          -0.032943
# genre           -0.071067
# year            -0.010431
# released        -0.012269
# score            0.001030
# votes            0.133204
# director         0.004404
# writer           0.005646
# star             0.012442
# country          0.095548
# budget           0.173214
# gross            0.154840
# company          1.000000
# runtime          0.034402
# corected_year   -0.012218
# dtype: float64

# %%
# According to this result we could see company

# %%
sorted_pairs = corr_pairs.sort_values()
sorted_pairs
# Out:
# budget         genre           -0.356564
# genre          budget          -0.356564
#                gross           -0.235650
# gross          genre           -0.235650
# rating         budget          -0.176002
# budget         rating          -0.176002
# genre          votes           -0.145307
# votes          genre           -0.145307
# score          country         -0.133348
# country        score           -0.133348
# rating         gross           -0.107339
# gross          rating          -0.107339
# genre          year            -0.081261
# year           genre           -0.081261
# corected_year  genre           -0.079415
# genre          corected_year   -0.079415
# country        runtime         -0.078412
# runtime        country         -0.078412
# country        corected_year   -0.078102
# corected_year  country         -0.078102
# company        genre           -0.071067
# genre          company         -0.071067
# year           country         -0.070938
# ...

# %%
high_corr = sorted_pairs[(sorted_pairs) > 0.5]
high_corr
# Out:
# gross          votes            0.630757
# votes          gross            0.630757
# budget         gross            0.740395
# gross          budget           0.740395
# year           corected_year    0.994831
# corected_year  year             0.994831
# name           name             1.000000
# company        company          1.000000
# gross          gross            1.000000
# budget         budget           1.000000
# country        country          1.000000
# star           star             1.000000
# writer         writer           1.000000
# director       director         1.000000
# votes          votes            1.000000
# score          score            1.000000
# released       released         1.000000
# year           year             1.000000
# genre          genre            1.000000
# rating         rating           1.000000
# runtime        runtime          1.000000
# corected_year  corected_year    1.000000
# dtype: float64
